# %%
# %matplotlib inline
from python_files.import_libs import *
from python_files.predict import *
from python_files.model import *

# %%
ts_data = pd.read_csv('data/arima_df.csv').set_index('date')

# %%
ts_data.index = pd.to_datetime(ts_data.index,errors='coerce')
ts_data
# Out:
#             sales_diff
# date
# 2015-02-01      4513.0
# 2015-03-01    157965.0
# 2015-04-01     64892.0
# 2015-05-01     80968.0
# 2015-06-01     32355.0
# 2015-07-01     60325.0
# 2015-08-01    -89161.0
# 2015-09-01    -76854.0
# 2015-10-01    -33320.0
# 2015-11-01     36056.0
# 2015-12-01   -186036.0
# 2016-01-01     19380.0
# 2016-02-01      3130.0
# 2016-03-01    175184.0
# 2016-04-01     84613.0
# 2016-05-01     93963.0
# 2016-06-01     23965.0
# 2016-07-01     82168.0
# 2016-08-01   -103414.0
# 2016-09-01   -100472.0
# 2016-10-01    -26241.0
# 2016-11-01     41900.0
# 2016-12-01   -222735.0
# 2017-01-01    -25535.0
# 2017-02-01     -1196.0
# 2017-03-01    179634.0
# 2017-04-01     93516.0
# 2017-05-01    102435.0
# 2017-06-01     10282.0
# 2017-07-01    100166.0
# 2017-08-01   -116949.0
# 2017-09-01    -97069.0
# 2017-10-01    -26079.0
# 2017-11-01     30392.0
# 2017-12-01   -220073.0
# 2018-01-01     -5133.0
# 2018-02-01     -4398.0
# 2018-03-01    192840.0
# 2018-04-01    111069.0
# 2018-05-01     86780.0
# 2018-06-01     33934.0
# 2018-07-01    116054.0
# 2018-08-01   -157224.0
# 2018-09-01    -84663.0
# 2018-10-01    -33194.0
# 2018-11-01     27811.0
# 2018-12-01   -228037.0
# 2019-01-01    -46105.0
# 2019-02-01      4063.0
# 2019-03-01    201298.0
# 2019-04-01    116195.0
# 2019-05-01     81824.0
# 2019-06-01     43938.0
# 2019-07-01    106769.0
# 2019-08-01   -144990.0
# 2019-09-01    -91140.0
# 2019-10-01    -44103.0
# 2019-11-01     37677.0
# 2019-12-01   -233667.0

# %%
# SARIMAX Modeling
sar, ts_data, predictions = arima_model(ts_data)
# Out:
# C:\Users\mathe\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# C:\Users\mathe\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# RMSE: 18634.397353981367
# Men Absolute Error: 14304.752428898493
# R2 Score: 0.9744987050154643

# %%
sar.plot_diagnostics(figsize=(10, 8));

# %%
# Plot results
print(len(predictions))
print('-------------------------------------------------')
print(predictions)
print('-------------------------------------------------')
original_df = load_original()
prediction_df = predict_data(predictions, original_df, False)
plot_results(prediction_df, original_df, 'arima')
# Out:
# 18
# -------------------------------------------------
# date
# 2018-07-01    103274.152175
# 2018-08-01   -122864.404427
# 2018-09-01    -95211.590694
# 2018-10-01    -27899.018070
# 2018-11-01     24126.764726
# 2018-12-01   -216846.520042
# 2019-01-01     -3231.889004
# 2019-02-01     -7276.997797
# 2019-03-01    196153.925246
# 2019-04-01    112067.872329
# 2019-05-01     83702.683252
# 2019-06-01     13053.085304
# 2019-07-01    102601.556656
# 2019-08-01   -124673.936619
# 2019-09-01    -94532.303926
# 2019-10-01    -29402.709343
# 2019-11-01     22393.637121
# 2019-12-01   -216117.344207
# Name: forecast, dtype: float64
# -------------------------------------------------
# <class 'numpy.float64'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-05492f0fcc46> in <module>
#       5 print('-------------------------------------------------')
#       6 original_df = load_original()
# ----> 7 prediction_df = predict_data(predictions, original_df)
#       8 plot_results(prediction_df, original_df, 'arima')
#
# ~\Downloads\Capstone Project\python_files\predict.py in predict_data(unscaled_predictions, original_data)
#      30         result_dict = {}
#      31         print(type(unscaled_predictions[x]))
# ---> 32         sum_predict = unscaled_predictions[x][0] + sales[x] if type(unscaled_predictions[x]) != "<class 'numpy.float64'>" else unscaled_predictions[x] + sales[x]
#      33         result_dict['predict_value'] = int(sum_predict)
#      34         result_dict['date'] = dates[x]
#
# IndexError: invalid index to scalar variable.
